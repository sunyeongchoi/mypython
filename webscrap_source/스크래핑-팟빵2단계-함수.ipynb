# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re
from itertools import count
from time import sleep

# 클리닝 함수 (file에 특수문자가 있을 경우 )
def clean_text(text):
    text = text.replace("\n", "")
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]',
                          '', text)
    return cleaned_text

# pid는 팟캐스트 하나하나의 id
def get_pang(pid):
    page_url = "http://www.podbbang.com/podbbangchnew/episode_list"
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
    }
    
    #for page_id in range(1,3):
    for page_id in count(1):#1부터 무한루프 -> try catch 해줘야함
        params_dict = {'id':pid, 'page':page_id}
        res = requests.get(page_url,params=params_dict, headers=headers)
        res.encoding = 'utf-8'
        html = res.text
        soup = BeautifulSoup(html,'html.parser')

        for li_tag in soup.select('li'):
            try:
                #print(li_tag)
                title = li_tag.find('dt')['title']
                #유료인 경우 a tag가 없으므로 한번 체크를 해준다.
                if li_tag.find('a'):
                    link = urljoin(page_url,li_tag.find('a')['href'])
                else:
                    link = None
                print(title,link)
            except(TypeError, KeyError):
                #li Tag가 없는 경우는 TypeError가 발생한다.
                print('END')
                return None
            else:
                req_headers={
                    'referer':'http://www.podbbang.com/ch/16255',
                    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36',
                }
                if link:
                    mp3_bin = requests.get(link, headers=req_headers).content
                    title = clean_text(title)
                    file_name = '{}.mp3'.format(title)
                    #print(file_name)
                    with open('MP3/'+file_name,'wb') as f:
                        f.write(mp3_bin)
                # sleep(10) : 10초간 프로세스 중지, 기계가 아니라 사람처럼 보이게 하기위한 위장
                sleep(0.5)

# %%
#여행바이러스 라디오(52건)
get_pang(16255)
# Out:
# 46. 소소하게 여행중독 #2 : 문상건 작가의 아시아와 세이셸 http://www.podbbang.com/download?pid=16255&eid=22816888
# 45. 소소하게 여행중독 - 문상건 작가의 인도 여행기 http://www.podbbang.com/download?pid=16255&eid=22810950
# 44. 여행직업탐구 : 국외여행인솔자 뽀개기 feat. 서주희 http://www.podbbang.com/download?pid=16255&eid=22795328
# 43. 코이카(KOICA) 뽀개기 feat.서주희 http://www.podbbang.com/download?pid=16255&eid=22792568
# 42. 6개월 동안의 신혼여행 feat 밤송이 http://www.podbbang.com/download?pid=16255&eid=22786239
# 춤추는 쥬디의 플래시몹 in 멕시코시티 http://www.podbbang.com/download?pid=16255&eid=22777956
# 41. 춤추는 쥬디의 멕시코 여행 http://www.podbbang.com/download?pid=16255&eid=22777932
# 40. 여행하다 배우다 : 남미에서 살사, 스페인어 정복하기 feat. 쥬디 http://www.podbbang.com/download?pid=16255&eid=22772684
# 39. 불의 나라 아제르바이잔, 바람의 도시 바쿠 feat 바쿠소녀 송의영 http://www.podbbang.com/download?pid=16255&eid=22766327
# 38. 조지아(Georgia)를 아시나요? feat 바쿠소녀 송의영 http://www.podbbang.com/download?pid=16255&eid=22760194
# 37. 세계의 지붕 파미르 고원을 넘다(키르기스스탄, 타지키스탄) - 자전거 여행가 김상아 http://www.podbbang.com/download?pid=16255&eid=22753111
dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 19.01.02</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:43:06</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22816888">6</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22816888" onclick="countEpisode('22816888');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class="deep epi22810950 " epiuid="22810950" id="episode_latest_22810950">
# <dl class="second" onclick="login_top.showEpisode('22810950', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="45. 소소하게 여행중독 - 문상건 작가의 인도 여행기">45. 소소하게 여행중독 - 문상건 작가의 인도 여행기</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.12.26</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:42:48</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22810950">13</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22810950" onclick="countEpisode('22810950');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class=" epi22795328 " epiuid="22795328" id="episode_latest_22795328">
# <dl class="second" onclick="login_top.showEpisode('22795328', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="44. 여행직업탐구 : 국외여행인솔자 뽀개기 feat. 서주희">44. 여행직업탐구 : 국외여행인솔자 뽀개기 feat. 서주희</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.12.19</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:45:09</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22795328">9</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22795328" onclick="countEpisode('22795328');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class="deep epi22792568 " epiuid="22792568" id="episode_latest_22792568">
# <dl class="second" onclick="login_top.showEpisode('22792568', 'audio/mpeg')" style="cursor:pointer;">
# <dt class="title_none" title="43. 코이카(KOICA) 뽀개기 feat.서주희">43. 코이카(KOICA) 뽀개기 feat.서주희</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.12.12</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:42:55</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22792568">10</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22792568" onclick="countEpisode('22792568');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class=" epi22786239 " epiuid="22786239" id="episode_latest_22786239">
# <dl class="second" onclick="login_top.showEpisode('22786239', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="42. 6개월 동안의 신혼여행 feat 밤송이">42. 6개월 동안의 신혼여행 feat 밤송이</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.12.05</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:53:25</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22786239">5</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22786239" onclick="countEpisode('22786239');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class="deep epi22777956 " epiuid="22777956" id="episode_latest_22777956">
# <dl class="first" onclick="login_top.showEpisode('22777956', 'video/mp4')" style="cursor:pointer;">
# <dt class="title_none" title="춤추는 쥬디의 플래시몹 in 멕시코시티">춤추는 쥬디의 플래시몹 in 멕시코시티</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.11.28</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:02:53</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22777956">4</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22777956" onclick="countEpisode('22777956');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class=" epi22777932 " epiuid="22777932" id="episode_latest_22777932">
# <dl class="second" onclick="login_top.showEpisode('22777932', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="41. 춤추는 쥬디의 멕시코 여행">41. 춤추는 쥬디의 멕시코 여행</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.11.28</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:49:12</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22777932">7</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22777932" onclick="countEpisode('22777932');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class="deep epi22772684 " epiuid="22772684" id="episode_latest_22772684">
# <dl class="second" onclick="login_top.showEpisode('22772684', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="40. 여행하다 배우다 : 남미에서 살사, 스페인어 정복하기 feat. 쥬디">40. 여행하다 배우다 : 남미에서 살사, 스페인어 정복하기 feat. 쥬디</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.11.21</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:42:37</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22772684">5</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22772684" onclick="countEpisode('22772684');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class=" epi22766327 " epiuid="22766327" id="episode_latest_22766327">
# <dl class="second" onclick="login_top.showEpisode('22766327', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="39. 불의 나라 아제르바이잔, 바람의 도시 바쿠 feat 바쿠소녀 송의영">39. 불의 나라 아제르바이잔, 바람의 도시 바쿠 feat 바쿠소녀 송의영</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.11.14</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:50:10</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22766327">7</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22766327" onclick="countEpisode('22766327');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- 유료 구매전 class 추가: cashlist -->
# <li class="deep epi22760194 " epiuid="22760194" id="episode_latest_22760194">
# <dl class="second" onclick="login_top.showEpisode('22760194', 'audio/mp3')" style="cursor:pointer;">
# <dt class="title_none" title="38. 조지아(Georgia)를 아시나요? feat 바쿠소녀 송의영">38. 조지아(Georgia)를 아시나요? feat 바쿠소녀 송의영</dt>
# <dd class="dd_date"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_up_2.gif"/> 18.11.07</dd>
# <dd class="dd_time"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_time.gif"/> 0:52:11</dd>
# <dd class="dd_heart"><img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/icon_heart_red.png"/> <span id="num_like22760194">13</span></dd>
# </dl>
# <!-- 19금 에피소드 다운로드 금지 -->
# <p class="download download_none">
# <a href="/download?pid=16255&amp;eid=22760194" onclick="countEpisode('22760194');fbq('track','EpisodeDownload');" target="_blank">
# <img alt="" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_download_n.png"/>
# </a>
# </p>
# </li>
# <!-- // 에피소드 영역 반복 -->
# </ul>
# </div>
# <style> .paging .current { color: #3b332b; font-weight: bold; text-decoration: underline;} </style><div class="paging epi_paging" id="epi_page_latest1"><span class="current">1</span> <a href="" onclick="episode_list('move_page', '2');return false;">2</a> <a href="" onclick="episode_list('move_page', '3');return false;">3</a> <a href="" onclick="episode_list('move_page', '4');return false;">4</a> <a href="" onclick="episode_list('move_page', '5');return false;">5</a> <a href="" onclick="episode_list('move_page', '6');return false;">6</a> <a href="" onclick="episode_list('move_page', '2');return false;"><img alt="다음" src="http://img.podbbang.com/img/h2/podbbang/individual/btn_page_right.gif"/></a></div>
# <script type="text/javascript">
# (function (EPISODES, IS_CH_SELL) {
#
#     var adultCount = 0,
#         episode_uids = [];
#
#     // @NOTE 하위 호환을 위해서 전역 변수에 대입함.
#     ischsell = IS_CH_SELL;
#
#     for (var i in EPISODES) {
#         var episodeId = EPISODES[i].uid;
#
#         if (! episode[episodeId]) {
#             if (EPISODES[i].pay_point > 0) {
#                 episode_uids.push(episodeId);
#             }
#
#             if (IS_CH_SELL == 'Y' && EPISODES[i].is_sell == 'Y') {
#                 episode_uids.push(episodeId);
#             }
#
#             episode[episodeId] = EPISODES[i];
#             episode[episodeId].autoplay = 'n';
#             episode[episodeId].ischsell = IS_CH_SELL;
#
#             if (episode[episodeId].adult == 'Y') adultCount += 1;
#         }
#     }
#
#     if (adultCount) {
#         $(window).load(function(){
#             setTimeout("login_top.checkBlind()", 1000);
#         });
#     }
#
#     if(episode_uids.length > 0) {
#         setTimeout(function () {
#             login_top.paid_check(episode_uids.join(','), IS_CH_SELL);
#         }, 2000);
#     }
#
# }) ([{"uid":"22816888","enclosure_type":"audio","pubdate":"20190102","encode_file":"http%3A%2F%2Ffile.ssenhosting.com%2Fdata1%2Fpb_21610%2Fyeovara46.mp3","share_enclosure_url":"aHR0cDovL2ZpbGUuc3Nlbmhvc3RpbmcuY29tL2RhdGExL3BiXzIxNjEwL3llb3ZhcmE0Ni5tcDM=","share_xml_url":"aHR0cDovL2NoLnBvZGJiYW5nLmNvbS94b