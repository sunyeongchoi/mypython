# %% [markdown]
# ### 기상청 날씨 데이터 조회
# * find(), find_all() 함수 사용

# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

res = requests.get(url)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
print(soup.find('title').string)
print(soup.find_all('title'))
print('---------------------------')
for title in soup.find_all('title'):
    print(title.text)
print('---------------------------')
print(soup.find('wf').string)
# Out:
# 기상청 육상 중기예보
# [<title>기상청 육상 중기예보</title>, <title>전국 육상 중기예보 - 2020년 07월 22일 (수)요일 06:00 발표</title>, <title>전국 육상중기예보</title>]
# ---------------------------
# 기상청 육상 중기예보
# 전국 육상 중기예보 - 2020년 07월 22일 (수)요일 06:00 발표
# 전국 육상중기예보
# ---------------------------
# ○ (강수) 25일(토)과 26일(일) 오전, 27일(월) 오후부터 30일(목)까지는 전국(30일 강원영동과 경남, 제주도 제외), 8월 1일(토)은 서울.경기도와 강원영서에 비가 오겠습니다.<br />○ (기온) 이번 예보기간의 낮 기온은 25~32도로 어제(28~32도)와 비슷하겠습니다.<br />○ (해상) 25일(토) 서해상과 남해상은 물결이 2.0~4.0m로 높게 일겠으니, 항해나 조업하는 선박은 유의하기 바랍니다.<br />○ (주말전망) 25일(토)은 대체로 흐리고 전국에 비가 오겠으며, 26일(일) 오전까지 비가 이어지겠습니다.<br />              아침 기온은 20~22도, 낮 기온은 25~29도의 분포를 보이겠습니다.<br /><br />* 이번 예보기간의 강수는 정체전선의 위치와 저기압의 이동경로에 따라 시점과 집중되는 지역이 변경될 가능성이 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.

# %%
for tag in soup.find_all('header'):
    print(tag.find('wf').string)
# Out:
# ○ (강수) 25일(토)과 26일(일) 오전, 27일(월) 오후부터 30일(목)까지는 전국(30일 강원영동과 경남, 제주도 제외), 8월 1일(토)은 서울.경기도와 강원영서에 비가 오겠습니다.<br />○ (기온) 이번 예보기간의 낮 기온은 25~32도로 어제(28~32도)와 비슷하겠습니다.<br />○ (해상) 25일(토) 서해상과 남해상은 물결이 2.0~4.0m로 높게 일겠으니, 항해나 조업하는 선박은 유의하기 바랍니다.<br />○ (주말전망) 25일(토)은 대체로 흐리고 전국에 비가 오겠으며, 26일(일) 오전까지 비가 이어지겠습니다.<br />              아침 기온은 20~22도, 낮 기온은 25~29도의 분포를 보이겠습니다.<br /><br />* 이번 예보기간의 강수는 정체전선의 위치와 저기압의 이동경로에 따라 시점과 집중되는 지역이 변경될 가능성이 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.

# %%
title = soup.find('location',attrs={'wl_ver':'3'}).find('province').text
city = soup.find('location',attrs={'wl_ver':'3'}).find('city').text
print(title)
print(city)
# Out:
# 서울ㆍ인천ㆍ경기도
# 서울

# %%
# 1개의 data는 dict에 저장하고, dict를 list에 저장한다.

data_tags = soup.find('location', attrs={'wl_ver':'3'}).find_all('data')
dict_tags = {}
list_tags = []
for tag in data_tags:
    mode = tag.find('mode').text
    dict_tags['mode'] = mode
    tmEf = tag.find('tmef').text
    dict_tags['tmef'] = tmEf
    wf = tag.find('wf').text
    dict_tags['wf'] = wf
    tmn = tag.find('tmn').text
    dict_tags['tmn'] = tmn
    tmx = tag.find('tmx').text
    dict_tags['tmx'] = tmx
    rnSt = tag.find('rnst').text
    dict_tags['rnst'] = rnSt
    list_tags.append(dict_tags)
    dict_tags = {}
    
print(list_tags)
# Out:
# [{'mode': 'A02', 'tmef': '2020-07-25 00:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-25 12:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 00:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 12:00', 'wf': '흐림', 'tmn': '21', 'tmx': '29', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 00:00', 'wf': '흐림', 'tmn': '22', 'tmx': '29', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '29', 'rnst': '90'}, {'mode': 'A02', 'tmef': '2020-07-28 00:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '28', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-28 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '28', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 12:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '29', 'rnst': '60'}, {'mode': 'A01', 'tmef': '2020-07-30 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '30', 'rnst': '80'}, {'mode': 'A01', 'tmef': '2020-07-31 00:00', 'wf': '흐림', 'tmn': '23', 'tmx': '29', 'rnst': '40'}, {'mode': 'A01', 'tmef': '2020-08-01 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '28', 'rnst': '80'}]

# %%
# JSON으로 변경

#태그 이름에 따른 값을 리턴해주는 함수
find_all_location = lambda val : soup.find('location', attrs={'wl_ver':'3'}).find_all(val)
find_location = lambda val2 : soup.find('location', attrs={'wl_ver':'3'}).find(val2).text


dict_tags = {}
list_tags = []
data_tags = find_all_location('data')
for tag in data_tags:
    mode = tag.find('mode').text
    dict_tags['mode'] = mode
    tmEf = tag.find('tmef').text
    dict_tags['tmef'] = tmEf
    wf = tag.find('wf').text
    dict_tags['wf'] = wf
    tmn = tag.find('tmn').text
    dict_tags['tmn'] = tmn
    tmx = tag.find('tmx').text
    dict_tags['tmx'] = tmx
    rnSt = tag.find('rnst').text
    dict_tags['rnst'] = rnSt
    list_tags.append(dict_tags)
    dict_tags = {}
#print(list_tags)    

dict_province = {}
list_province = []
province = find_location('province')
city = find_location('city')
dict_province['province'] = province
dict_province['city'] = city
dict_province['data'] = list_tags
list_province.append(dict_province)

# print(list_province)


#soup.find('body')
soup.find_all('location')
# print(len(soup.find_all('location'))) # 41개


dict_tags = {}
list_tags = []
dict_location_tag = {}
list_location_tag = []

for location_tag in soup.find_all('location'):
    #print(location_tag.find('province').text)
    #print(location_tag.find('city').text)
    for tag in location_tag.find_all('data'):
        mode = tag.find('mode').text
        #print(mode)
        dict_tags['mode'] = mode
        tmEf = tag.find('tmef').text
        dict_tags['tmef'] = tmEf
        wf = tag.find('wf').text
        dict_tags['wf'] = wf
        tmn = tag.find('tmn').text
        dict_tags['tmn'] = tmn
        tmx = tag.find('tmx').text
        dict_tags['tmx'] = tmx
        rnSt = tag.find('rnst').text
        dict_tags['rnst'] = rnSt
        
        list_tags.append(dict_tags)
        dict_tags = {}
    province = location_tag.find('province').text
    city = location_tag.find('city').text
    dict_location_tag['privince'] = province
    dict_location_tag['city'] = city
    dict_location_tag['data'] = list_tags
    list_location_tag.append(dict_location_tag)
print(list_location_tag)
# Out:
# [{'privince': '제주도', 'coty': '서귀포', 'data': [{'mode': 'A02', 'tmef': '2020-07-25 00:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-25 12:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 00:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 12:00', 'wf': '흐림', 'tmn': '21', 'tmx': '29', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 00:00', 'wf': '흐림', 'tmn': '22', 'tmx': '29', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '29', 'rnst': '90'}, {'mode': 'A02', 'tmef': '2020-07-28 00:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '28', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-28 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '28', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 12:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '29', 'rnst': '60'}, {'mode': 'A01', 'tmef': '2020-07-30 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '30', 'rnst': '80'}, {'mode': 'A01', 'tmef': '2020-07-31 00:00', 'wf': '흐림', 'tmn': '23', 'tmx': '29', 'rnst': '40'}, {'mode': 'A01', 'tmef': '2020-08-01 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '28', 'rnst': '80'}, {'mode': 'A02', 'tmef': '2020-07-25 00:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '28', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-25 12:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '28', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 00:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '27', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 12:00', 'wf': '흐림', 'tmn': '22', 'tmx': '27', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 00:00', 'wf': '흐림', 'tmn': '22', 'tmx': '27', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '27', 'rnst': '90'}, {'mode': 'A02', 'tmef': '2020-07-28 00:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '27', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-28 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '27', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '27', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 12:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '27', 'rnst': '60'}, {'mode': 'A01', 'tmef': '2020-07-30 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '27', 'rnst': '80'}, {'mode': 'A01', 'tmef': '2020-07-31 00:00', 'wf': '흐림', 'tmn': '23', 'tmx': '28', 'rnst': '40'}, {'mode': 'A01', 'tmef': '2020-08-01 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '27', 'rnst': '80'}, {'mode': 'A02', 'tmef': '2020-07-25 00:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-25 12:00', 'wf': '구름많고 비', 'tmn': '21', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 00:00', 'wf': '구름많고 비', 'tmn': '22', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-26 12:00', 'wf': '흐림', 'tmn': '22', 'tmx': '29', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 00:00', 'wf': '흐림', 'tmn': '22', 'tmx': '28', 'rnst': '40'}, {'mode': 'A02', 'tmef': '2020-07-27 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '28', 'rnst': '90'}, {'mode': 'A02', 'tmef': '2020-07-28 00:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '29', 'rnst': '70'}, {'mode': 'A02', 'tmef': '2020-07-28 12:00', 'wf': '흐리고 비', 'tmn': '22', 'tmx': '29', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '30', 'rnst': '60'}, {'mode': 'A02', 'tmef': '2020-07-29 12:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '30', 'rnst': '60'}, {'mode': 'A01', 'tmef': '2020-07-30 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '30', 'rnst': '80'}, {'mode': 'A01', 'tmef': '2020-07-31 00:00', 'wf': '흐림', 'tmn': '23', 'tmx': '30', 'rnst': '40'}, {'mode': 'A01', 'tmef': '2020-08-01 00:00', 'wf': '흐리고 비', 'tmn': '23', 'tmx': '29', 'rnst': '80'}, {'mode': 'A02', 'tmef': '2020-07-25 00:00', 'wf': '구름많고 비', 'tmn': '20',  ...
